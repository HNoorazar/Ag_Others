# %% [markdown]
# ### Linear Regression with annual data

# %%
from pysal.lib import weights
from pysal.model import spreg
from pysal.explore import esda

# %%
df_year.head(2)
# Out:
#   location  year  variety  yield  all_gdd  all_precip
# 0   Almira  2005   Alpowa   43.9  2181.91       102.1
# 1   Almira  2005  Alturas   37.7  2181.91       102.1

# %%
depen_var, indp_vars = "yield", ["all_precip"]

m5 = spreg.OLS_Regimes(y = df_year[depen_var].values, 
                       x = df_year[indp_vars].values, 
                       # Variable specifying neighborhood membership
                       regimes = df_year["variety"].tolist(),
              
                       # Variables to be allowed to vary (True) or kept
                       # constant (False). Here we set all to False
                       # cols2regi=[False] * len(indp_vars),
                        
                       # Allow the constant term to vary by group/regime
                       constant_regi="many",
                        
                       # Allow separate sigma coefficients to be estimated
                       # by regime (False so a single sigma)
                       regime_err_sep=False,
                       name_y=depen_var, # Dependent variable name
                       name_x=indp_vars)

m5_results = pd.DataFrame({"Coeff.": m5.betas.flatten(), # Pull out regression coefficients and
                           "Std. Error": m5.std_err.flatten(), # Pull out and flatten standard errors
                           "P-Value": [i[1] for i in m5.t_stat], # Pull out P-values from t-stat object
                           }, index=m5.name_x)

m5_results.transpose()
# Out:
#             Alpowa_CONSTANT  Alpowa_all_precip  Alturas_CONSTANT  \
# Coeff.         2.514453e+01       2.310937e-01         23.935455
# Std. Error     4.940779e+00       4.323352e-02          4.940779
# P-Value        3.950103e-07       1.011392e-07          0.000001
#
#             Alturas_all_precip  Babe_CONSTANT  Babe_all_precip  Diva_CONSTANT  \
# Coeff.            2.422625e-01   2.909115e+01     2.402135e-01   3.198295e+01
# Std. Error        4.323352e-02   3.862763e+00     3.816627e-02   3.791205e+00
# P-Value           2.405697e-08   7.718799e-14     3.832695e-10   6.391871e-17
#
#             Diva_all_precip  Louise_CONSTANT  Louise_all_precip  ...  \
# Coeff.         2.437202e-01     3.163481e+01       2.370203e-01  ...
# Std. Error     3.750425e-02     3.434939e+00       3.300679e-02  ...
# P-Value        1.033054e-10     8.359820e-20       9.882980e-13  ...
#
#             Tekoa_CONSTANT  Tekoa_all_precip  WB6341_CONSTANT  \
# Coeff.        2.634656e+01      3.409117e-01     3.172484e+01
# Std. Error    4.615909e+00      5.002990e-02     4.911326e+00
# P-Value       1.324699e-08      1.267595e-11     1.329772e-10
#
#             WB6341_all_precip  Wakanz_CONSTANT  Wakanz_all_precip  \
# Coeff.               0.269787     2.870797e+01       2.250852e-01
# Std. Error           0.055763     5.182867e+00       4.501767e-02
# P-Value              0.000001     3.464448e-08       6.260927e-07
#
#             Whit_CONSTANT  Whit_all_precip  Zak_CONSTANT  Zak_all_precip
# Coeff.       3.020965e+01     2.446203e-01  2.756133e+01        0.193969
# Std. Error   3.521175e+00     3.450669e-02  4.940779e+00        0.043234
# P-Value      1.943414e-17     1.894302e-12  2.775689e-08        0.000008
#
# [3 rows x 26 columns]

# %%
depen_var, indp_vars = "yield", ["all_gdd"]

m5 = spreg.OLS_Regimes(y = df_year[depen_var].values,  x = df_year[indp_vars].values, 
                       regimes = df_year["variety"].tolist(),
                       constant_regi="many",          
                       regime_err_sep=False,
                       name_y=depen_var,
                       name_x=indp_vars)

m5_results = pd.DataFrame({"Coeff.": m5.betas.flatten(), 
                           "Std. Error": m5.std_err.flatten(), # Pull out and flatten standard errors
                           "P-Value": [i[1] for i in m5.t_stat], # Pull out P-values from t-stat object
                           }, index=m5.name_x)

m5_results.transpose()
# Out:
#             Alpowa_CONSTANT  Alpowa_all_gdd  Alturas_CONSTANT  \
# Coeff.             7.181418        0.020464         13.744234
# Std. Error        18.192545        0.008670         18.192545
# P-Value            0.693075        0.018354          0.450050
#
#             Alturas_all_gdd  Babe_CONSTANT  Babe_all_gdd  Diva_CONSTANT  \
# Coeff.             0.017313      13.366908      0.017602      20.683885
# Std. Error         0.008670      15.996004      0.007378      15.268015
# P-Value            0.045966       0.403462      0.017137       0.175667
#
#             Diva_all_gdd  Louise_CONSTANT  Louise_all_gdd  ...  \
# Coeff.          0.015622        20.927292        0.015614  ...
# Std. Error      0.007026        13.766763        0.006405  ...
# P-Value         0.026308         0.128644        0.014874  ...
#
#             Tekoa_CONSTANT  Tekoa_all_gdd  WB6341_CONSTANT  WB6341_all_gdd  \
# Coeff.           15.786671       0.017746        15.634993        0.017035
# Std. Error       18.476196       0.008316        21.948366        0.009868
# P-Value           0.392973       0.032974         0.476333        0.084455
#
#             Wakanz_CONSTANT  Wakanz_all_gdd  Whit_CONSTANT  Whit_all_gdd  \
# Coeff.             8.466907        0.021433      18.126688      0.016292
# Std. Error        19.027066        0.009112      14.327168      0.006635
# P-Value            0.656376        0.018765       0.205956      0.014151
#
#             Zak_CONSTANT  Zak_all_gdd
# Coeff.         -2.664718     0.024434
# Std. Error     18.192545     0.008670
# P-Value         0.883563     0.004876
#
# [3 rows x 26 columns]

# %%
depen_var, indp_vars = "yield", ["all_gdd", "all_precip"]

m5 = spreg.OLS_Regimes(y=df_year[depen_var].values, x=df_year[indp_vars].values, 
                       regimes = df_year["variety"].tolist(),
                       constant_regi="many", regime_err_sep=False,
                       name_y=depen_var, name_x=indp_vars)

m5_results = pd.DataFrame({"Coeff.": m5.betas.flatten(),
                           "Std. Error": m5.std_err.flatten(),
                           "P-Value": [i[1] for i in m5.t_stat],}, 
                          index=m5.name_x)
m5_results.transpose()
# Out:
#             Alpowa_CONSTANT  Alpowa_all_gdd  Alpowa_all_precip  \
# Coeff.            11.489398        0.007212           0.218049
# Std. Error        16.600412        0.008373           0.045677
# P-Value            0.488950        0.389152           0.000002
#
#             Alturas_CONSTANT  Alturas_all_gdd  Alturas_all_precip  \
# Coeff.             18.426629         0.002909        2.369999e-01
# Std. Error         16.600412         0.008373        4.567723e-02
# P-Value             0.267136         0.728260        2.346210e-07
#
#             Babe_CONSTANT  Babe_all_gdd  Babe_all_precip  Diva_CONSTANT  ...  \
# Coeff.           3.111324      0.012434     2.313157e-01      11.142555  ...
# Std. Error      14.673365      0.006777     3.835051e-02      13.994995  ...
# P-Value          0.832100      0.066687     1.947435e-09       0.426026  ...
#
#             WB6341_all_precip  Wakanz_CONSTANT  Wakanz_all_gdd  \
# Coeff.               0.261102        12.545377        0.008580
# Std. Error           0.055958        17.360876        0.008799
# P-Value              0.000003         0.470001        0.329609
#
#             Wakanz_all_precip  Whit_CONSTANT  Whit_all_gdd  Whit_all_precip  \
# Coeff.               0.209725       9.448033      0.010045     2.360122e-01
# Std. Error           0.047556      13.116527      0.006115     3.479180e-02
# P-Value              0.000011       0.471420      0.100598     1.562667e-11
#
#             Zak_CONSTANT  Zak_all_gdd  Zak_all_precip
# Coeff.          0.659779     0.014208        0.168270
# Std. Error     16.600412     0.008373        0.045677
# P-Value         0.968301     0.089875        0.000236
#
# [3 rows x 39 columns]

# %%
depen_var, indp_vars = "yield", ["all_gdd", "all_precip"]

m5 = spreg.OLS(y = df_year[depen_var].values, x = df_year[indp_vars].values, 
               name_y=depen_var, name_x=indp_vars)

m5_results = pd.DataFrame({"Coeff.": m5.betas.flatten(),
                           "Std. Error": m5.std_err.flatten(),
                           "P-Value": [i[1] for i in m5.t_stat],}, 
                          index=m5.name_x)
m5_results.transpose()
# Out:
#             CONSTANT       all_gdd    all_precip
# Coeff.      3.690584  1.320452e-02  2.139795e-01
# Std. Error  4.331169  2.024280e-03  1.155770e-02
# P-Value     0.394265  8.775779e-11  1.449142e-70
